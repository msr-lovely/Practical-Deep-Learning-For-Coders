# %% [markdown]
# # Disclaimer
#
# This is my attempt to test the effectiveness of Progressive Resizing, TTA and Mixup for Image Classification (amongst other things).
#
# The final accuracy for our best Pokemon Classifier model is about **95.74%**.
#
# [Github](https://github.com/Melisa-Surja/Practical-Deep-Learning-For-Coders/tree/main/05-07) folder for this project.
#
# Course source from [Ch 7. Training a State-of-the-Art Model](https://github.com/fastai/fastbook/blob/master/07_sizing_and_tta.ipynb).
#
# Dataset from [Lance Zhang](https://www.kaggle.com/lantian773030/pokemonclassification).
#
# ~ Melisa Surja

# %% [markdown]
# # Installing Dependencies

# %%
# !pip install -Uqq fastbook
# !pip install kaggle
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.callback.fp16 import *

# %% [markdown]
# # Downloading Dataset
#
# We're going to use [Pokemon Dataset from Kaggle](https://www.kaggle.com/lantian773030/pokemonclassification).
#
# You need an API key to use the Kaggle API.
#
# How to get one:
# 1. Register an account from Kaggle
# 1. Click on your profile picture on the Kaggle website, and choose Account
# 1. Click Create New API Token. This will save a file called `kaggle.json` to your PC.
# 1. Put the `kaggle.json` file in `~/root/.kaggle/` folder

# %%
from kaggle import api
path = Path('Pokemon')
Path.BASE_PATH = path
path
# Out:
# Path('.')

# %% [markdown]
# Pro-tip: use the command `api.dataset_list(search='pokemon')` to get the dataset's reference name, `lantian773030/pokemonclassification`.

# %%
if not path.exists():
  path.mkdir(parents=true)
  api.dataset_download_files('lantian773030/pokemonclassification', path=path, unzip=true)
path.ls()
# Out:
# (#1) [Path('PokemonData')]

# %% [markdown]
# # Prepare Dataset
#
# The dataset contains `.svg` and other image file types that might cause errors, so let's limit our image files to `.jpg` and `.jpeg` files only.
#
# #### Data Augmentation
#
# I'm adding `mult=1.5` to amplify batch transformation effects. Don't pick a number that's too big because it might distort your images too much.

# %%
def get_dls(bs, size):
    dblock = DataBlock(blocks=(ImageBlock, CategoryBlock),
                   get_items=partial(get_files, extensions=['.jpg','.jpeg']),
                   get_y=parent_label,
                   splitter=RandomSplitter(seed=42),
                   item_tfms=Resize(460),
                   batch_tfms=[*aug_transforms(size=size, min_scale=0.75, mult=1.5), 
                               Normalize.from_stats(*imagenet_stats)])
    return dblock.dataloaders(path/'PokemonData', bs=bs, num_workers=0) #num_workers=0 for windows.

# %% [markdown]
# Tried `bs=512`, the model was less accurate overall and didn't improve training speedd at all.
#
# Size 32 or 64 didn't reduce learning time at all, they're all around 1:03

# %%
dls = get_dls(64, 96)
dls.train.show_batch(figsize=(6,6))

# %% [markdown]
# Let's view our data augmentation results. If the transformation results are too extreme, it can be reduced by reducing `mult` variable from DataBlock API.

# %%
dls.train.show_batch(max_n=10, nrows=2, unique=True)

# %% [markdown]
# # Start Training Model
#
# Not using `loss_func=CrossEntropyLossFlat()` because the accuracy is lower somehow?

# %%
learn = Learner(dls, xresnet152(n_out=dls.c), metrics=accuracy).to_fp16()

# %%
lr_min,lr_steep = learn.lr_find()
lr_min,lr_steep
# Out:
# (0.05248074531555176, 0.43651583790779114)

# %%
learn.fit_one_cycle(10, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.280869</td>
#       <td>4.130296</td>
#       <td>0.114264</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.876203</td>
#       <td>4.702787</td>
#       <td>0.105302</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.372243</td>
#       <td>3.326472</td>
#       <td>0.202390</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.687400</td>
#       <td>2.695168</td>
#       <td>0.323376</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.188360</td>
#       <td>2.182176</td>
#       <td>0.421957</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.762807</td>
#       <td>1.783878</td>
#       <td>0.532487</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.275650</td>
#       <td>1.386950</td>
#       <td>0.635549</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.968333</td>
#       <td>1.192333</td>
#       <td>0.691561</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.722489</td>
#       <td>1.035828</td>
#       <td>0.718447</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.585089</td>
#       <td>0.999632</td>
#       <td>0.727409</td>
#       <td>01:20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Using MixUp
#
# Let's make a second learner that uses MixUp to train.
#
# Pay attention that the learning rate for non-mixup and with-mixup learner are similar. MixUp takes 2-3 seconds longer to train.

# %%
learn2 = Learner(dls, xresnet152(n_out=dls.c), metrics=accuracy, cbs=MixUp()).to_fp16()

# %%
lr_min2,lr_steep2 = learn2.lr_find()
lr_min2,lr_steep2
# Out:
# (0.07585775852203369, 0.6309573650360107)

# %%
learn2.fit_one_cycle(10, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.439505</td>
#       <td>4.355733</td>
#       <td>0.076923</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.298513</td>
#       <td>4.613818</td>
#       <td>0.084391</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.805876</td>
#       <td>3.724484</td>
#       <td>0.162808</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.262786</td>
#       <td>3.419400</td>
#       <td>0.224795</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.827098</td>
#       <td>2.494491</td>
#       <td>0.375653</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.365754</td>
#       <td>1.920001</td>
#       <td>0.463779</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.946644</td>
#       <td>1.567828</td>
#       <td>0.586258</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.669619</td>
#       <td>1.292255</td>
#       <td>0.652726</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.409796</td>
#       <td>1.105889</td>
#       <td>0.699776</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.250272</td>
#       <td>1.078448</td>
#       <td>0.711725</td>
#       <td>01:20</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Mixup's improvement only starts showing after epoch #15.
#
# In the end, after 20 epochs mixup is about 1.4% more accurate.

# %% [markdown]
# # Using Pretrained Model

# %%
learn3 = cnn_learner(dls, resnet50, metrics=accuracy)

# %%
lr_min3,lr_steep3 = learn3.lr_find()
lr_min3,lr_steep3
# Out:
# (0.006918309628963471, 0.005248074419796467)

# %%
learn3.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.092159</td>
#       <td>1.869927</td>
#       <td>0.564600</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.124917</td>
#       <td>1.725654</td>
#       <td>0.604929</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.385163</td>
#       <td>0.944321</td>
#       <td>0.756535</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.834535</td>
#       <td>0.608909</td>
#       <td>0.829724</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.490545</td>
#       <td>0.551962</td>
#       <td>0.846154</td>
#       <td>01:02</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It's quite obvious that pretrained model outperforms all untrained models, even with basic options.

# %% [markdown]
# ### With .to_fp16()

# %%
learn6 = cnn_learner(dls, resnet50, metrics=accuracy).to_fp16()

# %%
lr_min6,lr_steep6 = learn6.lr_find()
lr_min6,lr_steep6
# Out:
# C:\Users\Melimeli\anaconda3\lib\site-packages\fastai\learner.py:54: UserWarning: Could not load the optimizer state.
#   if with_opt: warn("Could not load the optimizer state.")
# (0.006918309628963471, 0.004365158267319202)

# %%
learn6.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.263104</td>
#       <td>1.841170</td>
#       <td>0.557132</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.243373</td>
#       <td>1.821497</td>
#       <td>0.625840</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.551451</td>
#       <td>1.042650</td>
#       <td>0.744586</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.922154</td>
#       <td>0.654766</td>
#       <td>0.845407</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.606400</td>
#       <td>0.588028</td>
#       <td>0.850635</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Why is it not faster!!??!?!? Is 1-2 seconds faster the most you can get out of it??

# %% [markdown]
# ### With xresnet50

# %%
learn5 = cnn_learner(dls, partial(xresnet50,pretrained=True), metrics=accuracy)

# %%
lr_min5,lr_steep5 = learn5.lr_find()
lr_min5,lr_steep5
# Out:
# (0.003981071710586548, 0.001737800776027143)

# %%
learn5.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.952901</td>
#       <td>4.115457</td>
#       <td>0.158327</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.978424</td>
#       <td>3.049705</td>
#       <td>0.257655</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.938644</td>
#       <td>2.291463</td>
#       <td>0.398805</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.226468</td>
#       <td>1.942842</td>
#       <td>0.493652</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.745829</td>
#       <td>1.841244</td>
#       <td>0.522778</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Disappointing performance overall...

# %% [markdown]
# ## Deepest model
#
# I'm going to try using `resnet152` to find out its accuracy.

# %%
learn4 = cnn_learner(dls, resnet152, metrics=accuracy)

# %%
lr_min4,lr_steep4 = learn4.lr_find()
lr_min4,lr_steep4
# Out:
# (0.004786301031708717, 0.007585775572806597)

# %%
learn4.fit_one_cycle(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.901583</td>
#       <td>3.896984</td>
#       <td>0.393577</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.208215</td>
#       <td>2.090652</td>
#       <td>0.538462</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.388338</td>
#       <td>0.896799</td>
#       <td>0.761016</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.794020</td>
#       <td>0.559285</td>
#       <td>0.849888</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.482764</td>
#       <td>0.483693</td>
#       <td>0.864824</td>
#       <td>01:18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `resnet152` is about ~15 seconds longer to train per epoch than `resnet50`.

# %% [markdown]
# # Fine tuning with bigger images
#
# The most accurate learner of all 4 is `learn4`, by only ~1%.
#
# - Bigger images `size=224` with `bs=16` took about 02:03 = 123 seconds to train for one epoch with `resnet50`. With `resnet152`, they took 03:40 = 220 seconds.
# - Smaller images `size=96` with `bs=64` took about 01:03 = 63 seconds to train for one epoch with `resnet50`. With `resnet152`, they took 01:18 = 78 seconds.
#
# Due to the excess size (220+mb) and time spent training `resnet152`, it's best to use `resnet50` instead. File size for `resnet50` is aroundd `98mb`.

# %%
best_learner = learn3
best_learner.dls = get_dls(16, 224)

# %%
lr_min_final,lr_steep_final = best_learner.lr_find()
lr_min_final,lr_steep_final
# Out:
# (0.0015848932787775993, 0.005248074419796467)

# %%
best_learner.fine_tune(6, 5e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.310585</td>
#       <td>0.781383</td>
#       <td>0.803585</td>
#       <td>01:42</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.000625</td>
#       <td>0.790245</td>
#       <td>0.786408</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.158349</td>
#       <td>0.895951</td>
#       <td>0.773712</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.751288</td>
#       <td>0.455271</td>
#       <td>0.878267</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.480292</td>
#       <td>0.301027</td>
#       <td>0.921583</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.210910</td>
#       <td>0.217182</td>
#       <td>0.952203</td>
#       <td>02:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.126100</td>
#       <td>0.194159</td>
#       <td>0.957431</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Using TTA
#
# TTA improves accuracy by about ~1.2% percent.

# %%
preds,targs = best_learner.tta()
accuracy(preds, targs).item()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# 0.9589245915412903

# %% [markdown]
# # Let's test our model!

# %%
best_learner.show_results()

# %% [markdown]
# Let's see our most faulty predictions!

# %%
interp = ClassificationInterpretation.from_learner(best_learner)
interp.most_confused(min_val=3)
# Out:
# [('Kadabra', 'Alakazam', 3),
#  ('Kingler', 'Krabby', 3),
#  ('Marowak', 'Cubone', 3)]

# %% [markdown]
# Very interesting! The confusions come from pokemons from the same evolution line.
# Most people who don't know pokemons would probably think that they are the same pokemons as well, so our model has done well!

# %% [markdown]
# # Exporting the model

# %%
export_file_name = 'PokemonClassifier.pkl'
best_learner.export(fname=export_file_name)

# %% [markdown]
# # Error: CUDA out of memory
#
# If you get this error, free up your memory by deleting unused variables.

# %%
import torch
import gc
# del variable_names learn,learn2,learn3,dls
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# If it still doesn't work, shut down all kernels and restart the notebook.

# %% [markdown]
# # Load learner
#
# `load_learner` requires all your custom code be in the exact same place as when exporting your Learner (the main script, or the module you imported it from).

# %%
loaded_learner = load_learner(export_file_name)

# %%
loaded_learner.predict((path/'PokemonData/Arcanine').ls()[0])
# Out:
# ('Arcanine',
#  tensor(5),
#  tensor([6.4251e-09, 4.0905e-10, 2.5273e-08, 1.9916e-07, 2.8632e-10, 9.9991e-01, 5.0368e-08, 2.6586e-08, 9.7781e-10, 9.8572e-10, 3.8824e-11, 2.8209e-09, 1.6476e-11, 2.3252e-09, 5.1803e-10, 1.0566e-09,
#          3.5317e-12, 4.0890e-08, 2.6768e-08, 9.6970e-11, 2.1047e-07, 3.9032e-10, 4.0551e-10, 1.4475e-10, 2.8557e-09, 2.3544e-09, 5.5901e-11, 1.5020e-10, 7.8866e-10, 2.1220e-08, 3.5108e-11, 8.9490e-07,
#          7.5182e-10, 5.2757e-09, 2.7829e-08, 8.7329e-10, 2.9169e-09, 3.2561e-07, 7.0626e-07, 1.6582e-08, 2.6722e-10, 1.4027e-08, 2.3255e-10, 2.9187e-11, 3.0608e-11, 7.8088e-10, 8.1630e-08, 2.1169e-10,
#          1.7719e-09, 1.8388e-12, 9.8711e-06, 2.6562e-08, 4.1188e-08, 4.8702e-07, 2.2804e-10, 5.9501e-10, 3.7382e-10, 5.6079e-09, 1.3372e-11, 3.8795e-07, 1.8970e-08, 9.7897e-10, 5.4343e-08, 2.4293e-09,
#          1.7753e-09, 5.5761e-07, 3.5106e-11, 9.3854e-11, 4.6627e-12, 9.6866e-12, 1.7419e-10, 1.0766e-09, 2.4628e-08, 1.2671e-08, 1.4477e-11, 1.2339e-08, 2.4843e-12, 2.6444e-10, 4.4186e-07, 1.2297e-07,
#          6.3304e-10, 3.7219e-11, 2.3062e-10, 5.6166e-11, 8.3120e-09, 3.0612e-11, 1.9646e-10, 2.0389e-10, 1.2459e-09, 3.0681e-09, 6.5789e-09, 5.5793e-07, 2.1466e-09, 3.8542e-11, 3.2955e-11, 2.9805e-10,
#          1.0525e-11, 2.2487e-10, 5.3959e-08, 1.1246e-07, 3.4044e-07, 2.0038e-05, 2.2776e-08, 7.0636e-10, 3.0256e-10, 1.2195e-11, 2.7715e-10, 8.0148e-09, 3.3176e-12, 9.1335e-06, 3.9607e-09, 7.1483e-10,
#          1.5356e-08, 2.5035e-07, 2.3365e-09, 2.7905e-08, 1.1013e-09, 6.0016e-11, 4.3273e-07, 1.9978e-08, 3.3744e-09, 1.8478e-10, 1.3751e-09, 2.9245e-12, 1.5514e-11, 7.5160e-12, 3.4680e-09, 3.2664e-05,
#          3.6321e-10, 2.4412e-09, 5.1516e-10, 1.3657e-10, 2.4166e-08, 7.7811e-11, 8.8784e-10, 7.2662e-09, 1.1718e-09, 7.2414e-09, 4.4749e-10, 1.7199e-10, 2.0940e-11, 7.0635e-10, 8.0188e-10, 4.0713e-08,
#          4.6550e-10, 1.2161e-10, 2.8809e-10, 9.9594e-11, 1.0062e-05, 1.1174e-10]))
