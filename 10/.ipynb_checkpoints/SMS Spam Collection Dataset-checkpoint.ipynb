# %% [markdown]
# # About this project
#
# - Summarize your objectives for this NLP project - what you want to achieve
# > Being able to detect spam text messages
#
# - Describe the text preprocessing you do, including EDA
# > load csv file with pandas, remove duplicate data (about ~400 records are duplicates)
#
# - Build your model and pick relevant metrics. Train a baseline
# > Accuracy for metrics, baseline accuracy is about 65% for picking only ham
#
# - Show which approach you take to increase the performance of the model
# > Pretraining the model with Language Model before training a classifier and use the encoder

# %% [markdown]
# # Install Dependencies

# %%
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.text.all import *

# %% [markdown]
# # Load Data

# %%
ds_folder = Path('../../Datasets/SMS Spam Collection Dataset')
ds_sms = pd.read_csv(ds_folder/'spam.csv', 
                        usecols=[0,1],
                        names=['SPAM','Message'],
                        header=0, 
                        low_memory=False)
ds_sms.head()
# Out:
#    SPAM  \
# 0   ham
# 1   ham
# 2  spam
# 3   ham
# 4   ham
#
#                                                                                                                                                        Message
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1                                                                                                                                Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3                                                                                                            U dun say so early hor... U c already then say...
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though

# %% [markdown]
# # Sanitize Data
#
# - Drop duplicates
# - Class balance... even out the ratios of ham and spam

# %%
ds_sms.drop_duplicates(['Message'], inplace=True)

# %%
def ham_spam_ratio():
    print("ham: " + str(len(ds_sms[ds_sms['SPAM']=='ham'])/len(ds_sms)))
    print("spam: " + str(len(ds_sms[ds_sms['SPAM']=='spam'])/len(ds_sms)))
ham_spam_ratio()
# Out:
# ham: 0.873669955503966
# spam: 0.12633004449603405

# %%
len(ds_sms[ds_sms['SPAM']=='ham']), len(ds_sms[ds_sms['SPAM']=='spam'])
# Out:
# (4516, 653)

# %% [markdown]
# ### Let's remove 3k ham data

# %%
for i in range(0,3300):
    rand_del_idx = random.choice(ds_sms[ds_sms['SPAM']=='ham'].index)
    ds_sms.drop(rand_del_idx, axis='index', inplace=True)
ham_spam_ratio()
# Out:
# ham: 0.6506153023006955
# spam: 0.3493846976993044

# %% [markdown]
# # Sanitize Data

# %%
# random split
train_idx = []
valid_idx = []
train_sum = math.floor(len(ds_sms)*train_valid_perc)
for i in range(0,train_sum):
    train_idx.append(random.choice(ds_sms.index))

train_idx
# Out:
# [2977,
#  3553,
#  4617,
#  3639,
#  3790,
#  4514,
#  231,
#  3867,
#  2251,
#  1829,
#  3124,
#  2248,
#  5292,
#  3527,
#  2848,
#  5280,
#  4787,
#  4520,
#  4262,
#  4270,
#  769,
#  935,
#  1123,
#  968,
#  1639,
#  1031,
#  243,
#  1448,
#  1374,
#  107,
#  353,
#  2266,
#  1370,
#  4137,
#  363,
#  3412,
#  612,
#  5292,
#  226,
#  5017,
#  2444,
#  5185,
#  3332,
#  2690,
#  5082,
#  5137,
#  592,
#  4458,
#  5149,
#  1409,
#  2157,
#  4581,
#  1381,
#  1918,
#  3529,
#  460,
#  4601,
#  4033,
#  4827,
#  4861,
#  531,
#  5125,
#  1701,
#  4296,
#  843,
#  5060,
#  276,
#  5074,
#  870,
#  3219,
#  2251,
#  633,
#  776,
#  4965,
#  836,
#  1223,
#  886,
#  3263,
#  2333,
#  4078,
#  5200,
#  4597,
#  716,
#  1535,
#  8,
#  4281,
#  4656,
#  764,
#  3805,
#  1634,
#  1872,
#  1686,
#  791,
#  839,
#  1496,
#  4456,
#  3546,
#  878,
#  973,
#  1634,
#  1374,
#  121,
#  853,
#  1327,
#  4145,
#  764,
#  4680,
#  4206,
#  326,
#  88,
#  145,
#  571,
#  1075,
#  758,
#  2582,
#  3062,
#  3580,
#  975,
#  3203,
#  3939,
#  4034,
#  908,
#  1516,
#  3959,
#  1349,
#  1885,
#  353,
#  3844,
#  3489,
#  5074,
#  2792,
#  3358,
#  570,
#  4275,
#  1337,
#  1894,
#  1323,
#  4581,
#  922,
#  3582,
#  1827,
#  2153,
#  691,
#  3805,
#  2773,
#  2332,
#  1039,
#  3502,
#  1597,
#  5466,
#  4447,
#  4175,
#  2996,
#  1573,
#  2317,
#  4438,
#  2790,
#  4840,
#  2136,
#  1627,
#  326,
#  5500,
#  4638,
#  3135,
#  4559,
#  5492,
#  5237,
#  3554,
#  5294,
#  2619,
#  2639,
#  3434,
#  2058,
#  1220,
#  2136,
#  400,
#  5526,
#  1575,
#  11,
#  3258,
#  1071,
#  2,
#  3852,
#  2669,
#  234,
#  3559,
#  314,
#  2227,
#  1408,
#  5480,
#  1362,
#  2138,
#  323,
#  756,
#  2774,
#  1066,
#  5561,
#  721,
#  4326,
#  1889,
#  2405,
#  2691,
#  5096,
#  4357,
#  935,
#  2393,
#  400,
#  2805,
#  4507,
#  4734,
#  1108,
#  2444,
#  1063,
#  3497,
#  839,
#  1657,
#  1820,
#  4935,
#  3562,
#  4006,
#  3206,
#  3403,
#  2692,
#  4246,
#  2601,
#  5278,
#  2620,
#  1095,
#  3190,
#  4374,
#  4477,
#  1032,
#  4145,
#  1698,
#  1090,
#  2895,
#  878,
#  363,
#  1594,
#  2489,
#  944,
#  3538,
#  902,
#  943,
#  1055,
#  906,
#  3090,
#  5190,
#  1268,
#  1102,
#  3013,
#  4322,
#  4773,
#  486,
#  1102,
#  2872,
#  1847,
#  1008,
#  4327,
#  934,
#  1231,
#  1910,
#  3568,
#  155,
#  2191,
#  837,
#  2774,
#  4090,
#  146,
#  4656,
#  3440,
#  5250,
#  4229,
#  1657,
#  4971,
#  5178,
#  243,
#  5366,
#  4311,
#  4123,
#  570,
#  1591,
#  1694,
#  423,
#  982,
#  1772,
#  1914,
#  906,
#  1049,
#  3526,
#  875,
#  1443,
#  4930,
#  2088,
#  2217,
#  2555,
#  4059,
#  138,
#  3013,
#  3989,
#  5002,
#  3862,
#  3358,
#  1255,
#  3419,
#  4236,
#  1300,
#  5526,
#  5343,
#  4180,
#  3858,
#  1972,
#  195,
#  1594,
#  2363,
#  5555,
#  879,
#  4155,
#  3644,
#  4146,
#  1071,
#  1100,
#  3854,
#  2642,
#  1592,
#  670,
#  1997,
#  1100,
#  5218,
#  1929,
#  3260,
#  4975,
#  4938,
#  4381,
#  5409,
#  5274,
#  1343,
#  1149,
#  4281,
#  3013,
#  2580,
#  2935,
#  3856,
#  3449,
#  2066,
#  4781,
#  3722,
#  470,
#  4405,
#  5527,
#  4903,
#  3618,
#  120,
#  1922,
#  1384,
#  4606,
#  187,
#  3431,
#  3826,
#  4497,
#  1529,
#  1918,
#  3316,
#  2759,
#  2050,
#  3397,
#  1951,
#  344,
#  2935,
#  4188,
#  1049,
#  1951,
#  4920,
#  5555,
#  2722,
#  757,
#  1278,
#  1031,
#  4473,
#  4181,
#  4089,
#  1076,
#  85,
#  19,
#  2759,
#  15,
#  3296,
#  2391,
#  5342,
#  5437,
#  402,
#  3287,
#  2507,
#  3572,
#  4947,
#  1717,
#  2900,
#  5016,
#  1686,
#  2238,
#  4090,
#  2625,
#  1625,
#  2679,
#  4311,
#  3764,
#  4552,
#  1984,
#  961,
#  4490,
#  3698,
#  576,
#  1531,
#  3219,
#  1427,
#  4471,
#  2076,
#  3869,
#  2153,
#  5296,
#  2058,
#  240,
#  3277,
#  3817,
#  4656,
#  2155,
#  3401,
#  791,
#  3986,
#  5088,
#  803,
#  2639,
#  5120,
#  5275,
#  3950,
#  3,
#  4508,
#  984,
#  1885,
#  4972,
#  760,
#  4067,
#  4100,
#  2085,
#  4861,
#  4848,
#  3799,
#  4005,
#  4240,
#  1511,
#  5456,
#  3730,
#  606,
#  4822,
#  649,
#  4507,
#  3999,
#  357,
#  5456,
#  4532,
#  5343,
#  2083,
#  2010,
#  4458,
#  2330,
#  1014,
#  3910,
#  1717,
#  414,
#  823,
#  2404,
#  3940,
#  2317,
#  2574,
#  2390,
#  5480,
#  3860,
#  2924,
#  138,
#  4769,
#  3879,
#  3389,
#  5025,
#  1517,
#  276,
#  4458,
#  1785,
#  3383,
#  2289,
#  1706,
#  2766,
#  209,
#  1419,
#  1117,
#  2410,
#  4992,
#  1523,
#  973,
#  5102,
#  1638,
#  5110,
#  4618,
#  1846,
#  4583,
#  1109,
#  4278,
#  878,
#  128,
#  2453,
#  1814,
#  1543,
#  5173,
#  4374,
#  4409,
#  1278,
#  809,
#  2317,
#  3790,
#  378,
#  1672,
#  1255,
#  1687,
#  5294,
#  342,
#  4164,
#  3994,
#  5527,
#  5468,
#  5100,
#  4620,
#  5055,
#  1153,
#  2730,
#  413,
#  1951,
#  855,
#  5440,
#  5106,
#  4260,
#  1521,
#  1074,
#  4818,
#  712,
#  245,
#  3610,
#  367,
#  1892,
#  4061,
#  5115,
#  2333,
#  3109,
#  1415,
#  3895,
#  5564,
#  163,
#  3696,
#  5462,
#  4449,
#  2066,
#  1377,
#  4375,
#  457,
#  4513,
#  1055,
#  934,
#  2060,
#  934,
#  4450,
#  5233,
#  4656,
#  2282,
#  1576,
#  3493,
#  2562,
#  1608,
#  2516,
#  3229,
#  2664,
#  355,
#  2500,
#  2516,
#  3895,
#  3740,
#  4005,
#  2155,
#  1652,
#  1612,
#  934,
#  2920,
#  2357,
#  3746,
#  5295,
#  1332,
#  225,
#  2679,
#  3937,
#  4449,
#  163,
#  2648,
#  3036,
#  468,
#  4434,
#  234,
#  4406,
#  400,
#  4420,
#  225,
#  634,
#  787,
#  1669,
#  5092,
#  1651,
#  3030,
#  4656,
#  54,
#  2099,
#  2226,
#  3596,
#  3842,
#  1680,
#  756,
#  610,
#  668,
#  4458,
#  2936,
#  2759,
#  1744,
#  4289,
#  3489,
#  3909,
#  115,
#  135,
#  1594,
#  1465,
#  3481,
#  401,
#  5017,
#  318,
#  3932,
#  4726,
#  4353,
#  355,
#  2524,
#  969,
#  4183,
#  1082,
#  4125,
#  414,
#  4408,
#  5098,
#  4899,
#  1662,
#  3395,
#  985,
#  166,
#  1622,
#  3383,
#  3567,
#  1153,
#  91,
#  4273,
#  2359,
#  1639,
#  330,
#  5432,
#  1516,
#  504,
#  760,
#  421,
#  342,
#  2639,
#  236,
#  4031,
#  5147,
#  1573,
#  4109,
#  1147,
#  426,
#  158,
#  4841,
#  1969,
#  2090,
#  4769,
#  56,
#  1228,
#  517,
#  2063,
#  4383,
#  3013,
#  2955,
#  2623,
#  3230,
#  1796,
#  231,
#  2208,
#  2364,
#  89,
#  4651,
#  2463,
#  2573,
#  4926,
#  2021,
#  3883,
#  689,
#  1524,
#  689,
#  1516,
#  3013,
#  1306,
#  1951,
#  417,
#  1882,
#  2292,
#  119,
#  3352,
#  1992,
#  715,
#  1520,
#  4312,
#  764,
#  2638,
#  2707,
#  295,
#  4110,
#  878,
#  367,
#  1930,
#  4724,
#  1323,
#  3162,
#  2218,
#  680,
#  610,
#  1890,
#  727,
#  696,
#  468,
#  5537,
#  4249,
#  2495,
#  996,
#  5278,
#  4367,
#  2695,
#  5137,
#  571,
#  1465,
#  1153,
#  4536,
#  2088,
#  3675,
#  1083,
#  1504,
#  666,
#  220,
#  2234,
#  612,
#  3879,
#  5205,
#  2393,
#  1847,
#  61,
#  3773,
#  1459,
#  4180,
#  5338,
#  2861,
#  1059,
#  1801,
#  1969,
#  1220,
#  718,
#  5165,
#  4184,
#  220,
#  2848,
#  1114,
#  2867,
#  5482,
#  423,
#  1059,
#  839,
#  34,
#  2522,
#  838,
#  1826,
#  4427,
#  177,
#  3207,
#  3887,
#  1738,
#  1820,
#  4951,
#  4360,
#  4514,
#  1010,
#  1698,
#  115,
#  3228,
#  2984,
#  2512,
#  4311,
#  4795,
#  195,
#  4469,
#  3618,
#  2437,
#  4048,
#  3533,
#  752,
#  1801,
#  4618,
#  1323,
#  4943,
#  1346,
#  2312,
#  231,
#  585,
#  4034,
#  88,
#  3449,
#  4440,
#  3916,
#  3643,
#  3418,
#  1362,
#  4748,
#  423,
#  5060,
#  5323,
#  3527,
#  578,
#  4671,
#  4229,
#  5076,
#  1531,
#  4669,
#  342,
#  135,
#  4931,
#  3550,
#  3634,
#  4099,
#  2914,
#  673,
#  940,
#  5069,
#  4311,
#  5250,
#  3722,
#  2607,
#  4241,
#  649,
#  4795,
#  3494,
#  788,
#  3957,
#  4201,
#  5127,
#  4797,
#  3854,
#  1047,
#  2978,
#  3008,
#  2582,
#  5207,
#  5495,
#  1733,
#  4420,
#  450,
#  1892,
#  4254,
#  3528,
#  5269,
#  5521,
#  1469,
#  3713,
#  860,
#  4841,
#  2011,
#  1516,
#  3805,
#  1080,
#  1686,
#  4246,
#  1874,
#  4991,
#  251,
#  853,
#  2304,
#  2427,
#  1491,
#  3860,
#  986,
#  2733,
#  1391,
#  3097,
#  4253,
#  2491,
#  3726,
#  3553,
#  5190,
#  2238,
#  5098,
#  2513,
#  5466,
#  1592,
#  3228,
#  359,
#  5369,
#  490,
#  226,
#  1889,
#  402,
#  4618,
#  975,
#  3340,
#  3842,
#  4392,
#  788,
#  4184,
#  5368,
#  2685,
#  851,
#  4975,
#  1546,
#  1071,
#  114,
#  4443,
#  2426,
#  2821,
#  2695,
#  2852,
#  3680,
#  2983,
#  1342,
#  3966,
#  2194,
#  2622,
#  2641,
#  2924,
#  376,
#  65,
#  2824,
#  10,
#  2944,
#  4145,
#  5449,
#  786,
#  1441,
#  314,
#  2900,
#  3618,
#  4797,
#  1268,
#  3779,
#  2028,
#  490,
#  4285,
#  4156,
#  5242,
#  5426,
#  1248,
#  1076,
#  4488,
#  4601,
#  574,
#  2010,
#  2619,
#  3421,
#  1015,
#  323,
#  3317,
#  1024,
#  4033,
#  1422,
#  4795,
#  2489,
#  2194,
#  491,
#  5028,
#  4256,
#  2212,
#  3854,
#  935,
#  91,
#  480,
#  2575,
#  5017,
#  864,
#  3525,
#  4935,
#  1847,
#  4427,
#  694,
#  4078,
#  809,
#  2157,
#  3858,
#  5110,
#  ...]

# %%
clean_folder = Path(ds_folder/'clean')
train_folder = Path(clean_folder/'train')
valid_folder = Path(clean_folder/'valid')
train_valid_perc = 0.8 # how much of the file is train

# remove train and valid files if exist
if train_folder.exists():
    shutil.rmtree(train_folder)
os.mkdir(train_folder)
if valid_folder.exists():
    shutil.rmtree(valid_folder)
os.mkdir(valid_folder)

    
# Save to new folder
for index, row in ds_sms.iterrows():
    folder = train_folder if index in train_idx else valid_folder
    # ham or spam
    folder = Path(folder/row['SPAM'])
    # Make the folder if it doesn't exist yet
    if not folder.exists():
        os.mkdir(folder)
    filename = str(index) + ".txt"
    
    # Clean unicodes
    msg = re.sub('[\s\n]',' ', row['Message'])
    msg = re.sub('[^\w\.,:;\'\"\(\)\?\-!\n\s]', '', msg)
    
    # DELETE REMAINING UNICODES
    msg = msg.encode('ascii','ignore').decode('utf-8')
    
    clean_file = open(folder/filename, "w", encoding='utf8') 
    clean_file.write(msg)
    clean_file.close()

# %% [markdown]
# # Tokenize

# %%
# remove clean_tok dir
outdir = Path(ds_folder/'clean_tok')
if outdir.exists():
    shutil.rmtree(outdir)
    
# Save toks without error
tokenize_folder(clean_folder,folders=['train','valid'], n_workers=0)
# Out:
# Path('../../Datasets/SMS Spam Collection Dataset/clean_tok')

# %% [markdown]
# # Language Model Pretraining

# %%
dls_lm = DataBlock(
    blocks=TextBlock.from_folder(clean_folder, is_lm=True),
    get_items=partial(get_text_files, folders=['train', 'valid']), 
    splitter=GrandparentSplitter()
).dataloaders(clean_folder, path=clean_folder, bs=128, seq_len=80, num_workers=0)

# %%
dls_lm.show_batch(max_n=2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj xxunk you know is trying to contact you via our dating service ! xxmaj to find out who it could be call from your mobile or landline xxunk xxunk xxbos xxmaj omg how did u know what i xxunk ? xxbos xxup urgent . xxmaj important information for xxunk user . xxmaj today is your lucky day ! 2 find out why , log onto http : xxrep 3 w .urawinner.com there is a fantastic surprise awaiting you</td>
#       <td>xxmaj xxunk you know is trying to contact you via our dating service ! xxmaj to find out who it could be call from your mobile or landline xxunk xxunk xxbos xxmaj omg how did u know what i xxunk ? xxbos xxup urgent . xxmaj important information for xxunk user . xxmaj today is your lucky day ! 2 find out why , log onto http : xxrep 3 w .urawinner.com there is a fantastic surprise awaiting you !</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>your room number again ? xxmaj wanna make sure xxmaj i 'm xxunk on the right xxunk xxbos xxmaj save money on xxunk xxunk at xxrep 3 w xxunk xxmaj choose from a xxunk selection with national delivery . xxmaj brought to you by xxunk xxbos u have a xxmaj secret xxmaj admirer who is looking 2 make contact with xxmaj u - find out who they xxmaj rreveal who thinks xxup ur so special - call on xxunk xxbos</td>
#       <td>room number again ? xxmaj wanna make sure xxmaj i 'm xxunk on the right xxunk xxbos xxmaj save money on xxunk xxunk at xxrep 3 w xxunk xxmaj choose from a xxunk selection with national delivery . xxmaj brought to you by xxunk xxbos u have a xxmaj secret xxmaj admirer who is looking 2 make contact with xxmaj u - find out who they xxmaj rreveal who thinks xxup ur so special - call on xxunk xxbos xxmaj</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Train LM

# %%
learn = language_model_learner(
    dls_lm, AWD_LSTM, 
    metrics=Perplexity()).to_fp16()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.10964782238006592, lr_steep=0.17378008365631104)

# %%
learn.fine_tune(10, 5e-2, freeze_epochs=5, wd=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.907942</td>
#       <td>5.587443</td>
#       <td>267.051849</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.787554</td>
#       <td>5.052478</td>
#       <td>156.409622</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.528568</td>
#       <td>4.560366</td>
#       <td>95.618439</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.244355</td>
#       <td>4.167847</td>
#       <td>64.576279</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.976306</td>
#       <td>4.000480</td>
#       <td>54.624374</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.828574</td>
#       <td>3.997736</td>
#       <td>54.474678</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.742193</td>
#       <td>3.878116</td>
#       <td>48.333065</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.646329</td>
#       <td>3.815024</td>
#       <td>45.377831</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.530860</td>
#       <td>3.711012</td>
#       <td>40.895157</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.414492</td>
#       <td>3.694626</td>
#       <td>40.230526</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.316430</td>
#       <td>3.662787</td>
#       <td>38.969791</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.211174</td>
#       <td>3.675517</td>
#       <td>39.469070</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3.114846</td>
#       <td>3.671567</td>
#       <td>39.313461</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3.046485</td>
#       <td>3.671389</td>
#       <td>39.306477</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.980532</td>
#       <td>3.671269</td>
#       <td>39.301735</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save_encoder('SMS_LM_encoder')

# %% [markdown]
# # Classifier

# %%
db = DataBlock(
    blocks=(TextBlock.from_folder(clean_folder, vocab=dls_lm.vocab), CategoryBlock),
    get_y = parent_label,
    get_items=partial(get_text_files, folders=['train', 'valid']),
    splitter=GrandparentSplitter()
)

# %%
dls_clas = db.dataloaders(clean_folder, path=clean_folder, bs=128, seq_len=72, num_workers=0)

# %%
dls_clas.show_batch(max_n=3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj sad story of a xxmaj man - xxmaj last week was my b'day . xxmaj my xxmaj wife xxunk wish me . xxmaj my xxmaj parents forgot n so did my xxmaj kids . i went to work . xxmaj even my xxmaj xxunk did not wish . xxmaj as i entered my xxunk my xxup pa said , '' xxmaj happy xxmaj b'day xxmaj boss ! ! '' . i felt special . xxmaj she askd me 4 lunch . xxmaj after lunch she invited me to her xxunk . xxmaj we went there . xxmaj she said , ' ' do u mind if i go into the xxunk for a minute ? '' ' ' ok ' ' , i xxunk in a sexy xxunk . xxmaj she came out 5 xxunk xxunk wid a xxunk … n xxmaj my xxmaj wife , xxmaj my</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxbos no , i did n't mean to post it . i xxunk it , and like so many other times i 've xxunk stuff to you , i let it sit there . it xxup was what i was feeling at the time . i was angry . xxmaj before i left , i hit send , then stop . xxmaj it was n't there . i checked on my phone when i got to my car . xxmaj it was n't there . xxmaj you said you did n't sleep , you were bored . xxmaj so why would n't xxup that be the time to clean , xxunk xxunk , etc . ? xxmaj at least make the bed ?</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>xxbos xxmaj and that is the problem . xxmaj you walk around in xxunk " xxunk to what is going on around you . i say the same things xxunk and they go in one xxunk and out the other while you go off doing whatever you want to do . xxmaj it 's not that you do n't know why xxmaj i 'm xxunk xxunk it 's that you do n't listen when i tell you xxup what is going to xxunk me . xxmaj then you want to be xxunk when xxmaj i 'm mad . "</td>
#       <td>ham</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Train Classifier

# %%
learn2 = text_classifier_learner(dls_clas, AWD_LSTM, metrics=accuracy).to_fp16()

# %%
learn2 = learn2.load_encoder('SMS_LM_encoder')

# %%
learn2.fine_tune(10, 4e-3, freeze_epochs=5, wd=0.3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.883498</td>
#       <td>0.648109</td>
#       <td>0.866272</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.791167</td>
#       <td>0.364079</td>
#       <td>0.960947</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.743438</td>
#       <td>0.284815</td>
#       <td>0.955030</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.703307</td>
#       <td>0.224598</td>
#       <td>0.971598</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.677287</td>
#       <td>0.178113</td>
#       <td>0.972781</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.567709</td>
#       <td>0.185519</td>
#       <td>0.966864</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.551579</td>
#       <td>0.170425</td>
#       <td>0.970414</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.535399</td>
#       <td>0.148233</td>
#       <td>0.971598</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.511822</td>
#       <td>0.103072</td>
#       <td>0.973965</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.481555</td>
#       <td>0.137627</td>
#       <td>0.971598</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.454111</td>
#       <td>0.096460</td>
#       <td>0.975148</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.432300</td>
#       <td>0.126482</td>
#       <td>0.970414</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.407730</td>
#       <td>0.104811</td>
#       <td>0.973965</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.388558</td>
#       <td>0.103850</td>
#       <td>0.973965</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.371956</td>
#       <td>0.099810</td>
#       <td>0.973965</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#       <th>category_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj one day a crab was running on the sea xxunk .. the xxunk came n cleared the footprints of the crab .. xxmaj crab asked : being my frnd y r u xxunk my beautiful footprints ? xxmaj xxunk xxunk : a xxunk was following ur footprints to catch you ! that s y i cleared it off : ) xxunk never lets u xxunk :-) xxup gud nyt ..</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxbos xxmaj you are a great role xxunk . xxmaj you are giving so much and i really wish each day for a xxunk but xxmaj god as a reason for everything and i must say i wish i knew why but i do nt . xxmaj i 've looked up to you since i was xxunk and i still do . xxmaj have a great day .</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>xxbos xxmaj ha ha xxunk xxunk xxunk .. xxunk xxunk chikku , u xxunk many things xxunk me .. so far i did n't told any xxunk and even xxunk a word abt u .. xxmaj if ur xxunk me so much how can i tell these to xxunk .. xxmaj plz xxunk time do nt use those words to me .. ok , xxunk )</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>xxbos xxup asked xxunk xxup if 0870 xxup xxunk xxup xxunk xxup in xxup free xxup mins . xxup xxunk xxup cust xxunk xxup xxunk xxup yes . xxup xxunk xxup got xxup xxunk xxup bill . 3 xxup do nt xxup xxunk a xxup shit . xxup xxunk xxup due xxup in xxup days . i o 250 3 xxup want 800</td>
#       <td>spam</td>
#       <td>spam</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>xxbos xxmaj nothing . i meant that once the money xxunk your account here , the bank will remove its xxunk rate . xxmaj someone xxunk lt;gt ; to my account and lt;gt ; xxunk got xxunk . xxmaj so the xxunk xxunk and charges also xxunk sure you trust the xxunk person you are sending account details to cos …</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>xxbos i xxunk the test yesterday . xxmaj its something that lets you know the xxunk day u xxunk will get xxunk in about 2 to xxunk . xxmaj but pls pls do nt xxunk . i know u r xxunk . xxmaj pls xxunk . xxmaj also is there anything in ur past xxunk u need to tell me ?</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>xxbos xxmaj oh xxunk it . xxmaj omg yesterday i had a dream that i had 2 kids both boys . i was so xxunk . xxmaj not only about the kids but them being boys . i even told xxunk in my dream that he was xxunk xxunk cause xxmaj i 'm not getting xxunk in the face .</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>xxbos xxup urgent , xxup important xxup information xxup for xxup o2 xxup user . xxup today xxup is xxup your xxup lucky xxup day ! 2 xxup find xxup out xxup why xxup log xxup onto xxup http : xxrep 3 w .urawinner.com xxup there xxup is a xxup fantastic xxup surprise xxup awaiting xxup for xxup you</td>
#       <td>spam</td>
#       <td>spam</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>xxbos xxup xxunk xxup xxunk u xxup up 2 2nite ? xxup did nt xxup end xxup up xxup goin xxup down xxup town xxup jus xxup da xxup pub xxup xxunk ! xxup jus xxup xxunk xxup at xxup da xxup mo xxup in xxup me xxup xxunk xxup xxunk xxrep 3 x . " "</td>
#       <td>ham</td>
#       <td>ham</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Save Model

# %%
learn2.export(fname='models/sms_spam.pkl')
